# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Avinash Gokhane\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[["education_of_employee"]]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
unique_cnt=visa_df["education_of_employee"].unique()
unique_cnt
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
len(unique_cnt)
# Out:
# 4

# %%
cdf=visa_df["education_of_employee"].value_counts()
cdf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
cdf.keys()
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
cdf.values
# Out:
# array([10234,  9634,  3420,  2192], dtype=int64)

# %%
unique_cnt=visa_df["education_of_employee"].unique()
count_list=[]
for i in unique_cnt:
    con=visa_df["education_of_employee"]==i
    val=len(visa_df[con])
    count_list.append(val)
    print(i,val)
# Out:
# High School 3420
# Master's 9634
# Bachelor's 10234
# Doctorate 2192

# %%
employee_df= pd.DataFrame(zip(unique_cnt,count_list),
             columns=["education_of_employee","count"])
employee_df
# Out:
#   education_of_employee  count
# 0           High School   3420
# 1              Master's   9634
# 2            Bachelor's  10234
# 3             Doctorate   2192

# %%
plt.bar("education_of_employee","count",data=employee_df)
plt.title("Barchart")
plt.xlabel("Degree")
plt.ylabel("Count")
plt.savefig(r"C:\Users\avina\OneDrive\Documents\NareshIT\DATA SCIENCE & AI\EDA Python\Barchart_education_of_employee.jpg")
plt.show()

# %%
cdf=visa_df["education_of_employee"].value_counts()
cdf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
cdf.keys
# Out:
# <bound method Series.keys of education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64>

# %%
cdf=visa_df["education_of_employee"].value_counts()
keys=cdf.keys()
sns.countplot(data=visa_df,
              x="education_of_employee",
              order=keys)
plt.title("Bargraph_education_of_employee")
plt.xlabel("Degree")
plt.ylabel("Count")
plt.savefig(r"C:\Users\avina\OneDrive\Documents\NareshIT\DATA SCIENCE & AI\EDA Python\Barchart_education_of_employee.jpg")
plt.show()

# %%
cdf=visa_df["education_of_employee"].value_counts()
ax=cdf.plot(kind="bar")
plt.title("Barchart")
ax.bar_label(ax.containers[0])
plt.show()

# %%
cdf=visa_df["education_of_employee"].value_counts(normalize=True)
cdf
# Out:
# education_of_employee
# Bachelor's     0.401648
# Master's       0.378100
# High School    0.134223
# Doctorate      0.086028
# Name: proportion, dtype: float64

# %%
cdf=visa_df["education_of_employee"].value_counts()
cdf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
cdf=visa_df["education_of_employee"].value_counts()
keys=cdf.keys
keys
cdf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
cdf=visa_df["education_of_employee"].value_counts()
keys=cdf.keys()
values=cdf.values
plt.pie(values,
        explode=[0.1,0.1,0.1,0.1],  #for expanding your circle
        labels=keys,
       autopct="%0.2f%%",#2f means want values after point
       startangle=180,
       radius=1)  
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
california_housing=pd.read_csv(r"C:\Users\avina\OneDrive\Documents\NareshIT\DATA SCIENCE & AI\Data files\california_housing.csv")
california_housing
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
california_housing[["HouseAge"]]
# Out:
#        HouseAge
# 0            41
# 1            21
# 2            52
# 3            52
# 4            52
# ...         ...
# 20635        25
# 20636        18
# 20637        17
# 20638        18
# 20639        16
#
# [20640 rows x 1 columns]

# %%
hdf=california_housing["HouseAge"].value_counts()
hdf
keys=hdf.keys
keys
hdf
# Out:
# HouseAge
# 52    1273
# 36     862
# 35     824
# 16     771
# 17     698
# 34     689
# 26     619
# 33     615
# 18     570
# 25     566
# 32     565
# 37     537
# 15     512
# 19     502
# 27     488
# 24     478
# 30     476
# 28     471
# 20     465
# 29     461
# 31     458
# 23     448
# 21     446
# 14     412
# 22     399
# 38     394
# 39     369
# 42     368
# 44     356
# 43     353
# 40     304
# 13     302
# 41     296
# 45     294
# 10     264
# 11     254
# 46     245
# 5      244
# 12     238
# 8      206
# 9      205
# 47     198
# 4      191
# 48     177
# 7      175
# 6      160
# 50     136
# 49     134
# 3       62
# 2       58
# 51      48
# 1        4
# Name: count, dtype: int64

# %%
unique_cnt=california_housing["HouseAge"].unique()
count_list=[]
for i in unique_cnt:
    con=california_housing["HouseAge"]==i
    val=len(california_housing[con])
    count_list.append(val)
    print(i,val)
# Out:
# 41 296
# 21 446
# 52 1273
# 42 368
# 50 136
# 40 304
# 49 134
# 48 177
# 51 48
# 43 353
# 2 58
# 46 245
# 26 619
# 20 465
# 17 698
# 36 862
# 19 502
# 23 448
# 38 394
# 35 824
# 10 264
# 16 771
# 27 488
# 39 369
# 31 458
# 29 461
# 22 399
# 37 537
# 28 471
# 34 689
# 32 565
# 47 198
# 44 356
# 30 476
# 18 570
# 45 294
# 33 615
# 24 478
# 15 512
# 14 412
# 13 302
# 25 566
# 5 244
# 12 238
# 6 160
# 8 206
# 9 205
# 7 175
# 3 62
# 4 191
# 11 254
# 1 4

# %%
house_df= pd.DataFrame(zip(unique_cnt,count_list),
             columns=["HouseAge","count"])
house_df
# Out:
#     HouseAge  count
# 0         41    296
# 1         21    446
# 2         52   1273
# 3         42    368
# 4         50    136
# 5         40    304
# 6         49    134
# 7         48    177
# 8         51     48
# 9         43    353
# 10         2     58
# 11        46    245
# 12        26    619
# 13        20    465
# 14        17    698
# 15        36    862
# 16        19    502
# 17        23    448
# 18        38    394
# 19        35    824
# 20        10    264
# 21        16    771
# 22        27    488
# 23        39    369
# 24        31    458
# 25        29    461
# 26        22    399
# 27        37    537
# 28        28    471
# 29        34    689
# 30        32    565
# 31        47    198
# 32        44    356
# 33        30    476
# 34        18    570
# 35        45    294
# 36        33    615
# 37        24    478
# 38        15    512
# 39        14    412
# 40        13    302
# 41        25    566
# 42         5    244
# 43        12    238
# ...

# %%
plt.bar("HouseAge","count",data=house_df)
#plt.figure(figsize=(8,6))
plt.title("California_housing_barchart")
plt.xlabel("HouseAge")
plt.ylabel("Count")
plt.savefig(r"C:\Users\avina\OneDrive\Documents\NareshIT\DATA SCIENCE & AI\EDA Python\california_housing_barchart.jpg")
plt.show()

# %%
hdf=california_housing["HouseAge"].value_counts()
keys=hdf.keys()
sns.countplot(data=california_housing,
              x="HouseAge",
              order=keys)
plt.title("California_housing_barchart")
plt.xlabel("HouseAge")
plt.ylabel("Count")
plt.savefig(r"C:\Users\avina\OneDrive\Documents\NareshIT\DATA SCIENCE & AI\EDA Python\california_housing_barchart.jpg")
plt.show()

# %%
# Out:
# 52

# %%
hdf=california_housing["HouseAge"].value_counts()
keys=hdf.keys()
values=hdf.values
plt.pie(values,
        labels=keys,
       autopct="%0.2f%%",#2f means want values after point
       startangle=180,
       radius=1)  
plt.show()
